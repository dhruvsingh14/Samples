# %% [markdown]
# #### Analyst: Dhruv Singh <br> Report Name: Director's Request, Part 2 <br> Report Quarter, Year: FY 2018-2020 <br> Date Updated: 08/23/2021

# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_data.csv')

# %%
df.head()
# Out:
#    State Id              Program Title  ServiceCode  \
# 0     37124  DC Infrastructure Academy          101
# 1     37124  DC Infrastructure Academy          102
# 2     37124  DC Infrastructure Academy          138
# 3     37124  DC Infrastructure Academy          328
# 4     37124  DC Infrastructure Academy          608
#
#                              ServiceTitle ActualStartDate ActualEndDate  \
# 0                             Orientation       6/18/2018     6/18/2018
# 1                      Initial Assessment       6/18/2018     6/18/2018
# 2                       Career Counseling       6/18/2018     6/18/2018
# 3  Occupational Skills Training (Non-ITA)       6/18/2018     11/1/2018
# 4                        1K Opportunities       6/25/2018     3/26/2019
#
#         CompletionStatus                           ServiceProviderName  \
# 0  Successful Completion          DC Department of Employment Services
# 1  Successful Completion          DC Department of Employment Services
# ...

# %% [markdown]
# #### Subsetting 2: Line Graphs

# %%
df1 = df[['State Id', 'ServiceProviderName', 'CourseName', 'ExitDate', 'Year']]

# %%
df1 = df1.sort_values(by=['Year', 'State Id', 'ExitDate'], ascending = (True, True, False))

# %%
df1.shape
# Out:
# (1357, 5)

# %%
df1 = df1.drop_duplicates(subset = ['State Id'], keep='first')

# %%
df1.head()
# Out:
#      State Id                   ServiceProviderName  \
# 400      2181  DC Department of Employment Services
# 430      3916  DC Department of Employment Services
# 850      4831  DC Department of Employment Services
# 379      5859  DC Department of Employment Services
# 223      6667                                     0
#
#                                      CourseName   ExitDate  Year
# 400  Services to Individuals Seeking Employment  5/20/2019  2018
# 430  Services to Individuals Seeking Employment  1/23/2020  2018
# 850  Services to Individuals Seeking Employment   3/2/2020  2018
# 379  Services to Individuals Seeking Employment  2/26/2020  2018
# 223                                           0   3/2/2020  2018

# %%
df1.shape
# Out:
# (492, 5)

# %% [markdown]
# #### Line Graph 1: Total Number by Service Provider

# %%
df2 = df1[['Year', 'ServiceProviderName', 'State Id']].groupby(['Year', 'ServiceProviderName']).count()

# %%
df2
# Out:
#                                                          State Id
# Year ServiceProviderName
# 2018 0                                                         12
#      CC Prep - MLK                                             17
#      Community Tech LLC                                         1
#      DC Department of Employment Services                     148
#      DC Department of Fire & Emergency Services                 1
#      Excel Automotive Institute                                 6
#      GRID Alternatives Mid-Atlantic                            12
#      ITC Technologies LLC                                       2
#      The Training Zone of the DMV                              65
#      University of the District of Columbia (UDC)               1
# 2019 CC Prep - MLK                                             15
#      DC Department of Employment Services                       1
#      DC Department of Fire & Emergency Services                 7
# ...

# %%
df2 = df2.reset_index()
df2 = df2.rename(columns = {"State Id": "Number Employed"})

# %%
df2.head()
# Out:
#    Year                         ServiceProviderName  Number Employed
# 0  2018                                           0               12
# 1  2018                               CC Prep - MLK               17
# 2  2018                          Community Tech LLC                1
# 3  2018        DC Department of Employment Services              148
# 4  2018  DC Department of Fire & Emergency Services                1

# %%
df2_long = df2.pivot_table(index='Year', columns='ServiceProviderName', values='Number Employed').reset_index()

# %%
df2_long = df2_long.fillna(0)

# %%
df2_long = df2_long.set_index('Year')

# %%
df2_long
# Out:
# ServiceProviderName     0  Art and Soul Solutions, Inc.  CC Prep - MLK  \
# Year
# 2018                 12.0                           0.0           17.0
# 2019                  0.0                           0.0           15.0
# 2020                  0.0                           0.0            0.0
# 2021                  0.0                           2.0            0.0
#
# ServiceProviderName  CNI, LLC  Community Tech LLC  \
# Year
# 2018                      0.0                 1.0
# 2019                      0.0                 0.0
# 2020                      6.0                 0.0
# 2021                      0.0                 0.0
#
# ServiceProviderName  DC Department of Employment Services  \
# Year
# 2018                                                148.0
# 2019                                                  1.0
# 2020                                                  0.0
# 2021                                                 15.0
#
# ...

# %%
# df2_long.to_csv('service_provider.csv')

# %%
df2_long = df2_long[['The Training Zone of the DMV', 'DC Department of Employment Services', 'CC Prep - MLK', 'GRID Alternatives Mid-Atlantic', 'University of the District of Columbia (UDC)']]

# %%
df2_long = df2_long.rename(columns = {'The Training Zone of the DMV': 'DMV', 
                                      'DC Department of Employment Services': 'DOES', 
                                      'CC Prep - MLK': 'MLK', 
                                      'GRID Alternatives Mid-Atlantic': 'GRID', 
                                      'University of the District of Columbia (UDC)': 'UDC'})

# %%
## comparing service providers
df2_long.plot(kind='line')
plt.title('Total Employment by Service Provider')
plt.ylabel('Number Employed')
plt.xlabel('Year')
plt.xticks([2018, 2019, 2020, 2021])
plt.savefig('graphs/service_provider.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Line Graph 2: Total Number by Course Name

# %%
df3 = df1[['Year', 'CourseName', 'State Id']].groupby(['Year', 'CourseName']).count()

# %%
df3
# Out:
#                                                  State Id
# Year CourseName
# 2018 0                                                 12
#      Automotive Foundations                             6
#      First Aid/CPR/AED Training                         1
#      Flagger/OSHA 10 Safety Training                   65
#      Help Desk IT Training                             19
#      Quick Path to Energy                               1
#      Services to Individuals Seeking Employment       148
#      Solar Works                                       12
#      Work Readiness                                     1
# 2019 Automotive Foundations                             3
#      Automotive- Brakes                                 1
#      Cisco Certified Network Associate (CCNA)           7
#      Commercial Driver's License Class B                2
#      CompTIA A+                                         4
#      First Aid/CPR/AED Training                         7
# ...

# %%
df3 = df3.reset_index()
df3 = df3.rename(columns = {"State Id": "Number Employed"})

# %%
df3_long = df3.pivot_table(index='Year', columns='CourseName', values='Number Employed').reset_index()

# %%
df3_long = df3_long.fillna(0)

# %%
df3_long = df3_long.set_index('Year')

# %%
df3_long
# Out:
# CourseName     0  Automotive Foundations  Automotive- Brakes  Bank on DC  \
# Year
# 2018        12.0                     6.0                 0.0         0.0
# 2019         0.0                     3.0                 1.0         0.0
# 2020         0.0                     0.0                 0.0         0.0
# 2021         0.0                     0.0                 0.0         1.0
#
# CourseName  Cisco Certified Network Associate (CCNA)  \
# Year
# 2018                                             0.0
# 2019                                             7.0
# 2020                                             0.0
# 2021                                             0.0
#
# CourseName  Commercial Driver's License Class B  CompTIA A+  \
# Year
# 2018                                        0.0         0.0
# 2019                                        2.0         4.0
# 2020                                        0.0         0.0
# 2021                                        0.0         0.0
#
# ...

# %%
# df3_long.to_csv('course_title.csv')

# %%
df3_long = df3_long[['Services to Individuals Seeking Employment', 'Flagger/OSHA 10 Safety Training', 'Help Desk IT Training', 'Solar Works', 'Quick Path to Energy', 'OSHA 30']]

# %%
df3_long = df3_long.rename(columns = {'Services to Individuals Seeking Employment': 'Serv Indiv.', 
                                      'Flagger/OSHA 10 Safety Training': 'OSHA 10', 
                                      'Help Desk IT Training': 'HlpDsk IT', 
                                      'Solar Works': 'Solar', 
                                      'Quick Path to Energy': 'Qck Pth', 
                                      'OSHA 30': 'OSHA 30'})

# %%
## comparing course titles
df3_long.plot(kind='line')
plt.title('Total Employment by Course Title')
plt.ylabel('Number Employed')
plt.xlabel('Year')
plt.xticks([2018, 2019, 2020, 2021])
plt.savefig('graphs/course_title.png', dpi=300, bbox_inches='tight')
plt.show()
