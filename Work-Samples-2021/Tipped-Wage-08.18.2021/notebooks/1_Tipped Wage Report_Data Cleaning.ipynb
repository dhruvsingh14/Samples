# %% [markdown]
# # Tipped Wage Report: Data Cleaning

# %% [markdown]
# #### Analyst: Dhruv Singh <br> Report Name: Tipped Wage Report, Part 1 <br> Report Quarter, Year: Q2 2021 <br> Date Updated: 08/18/2021

# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %% [markdown]
# ### Reading in Data

# %%
essp = pd.read_csv('data/ESSP - 2021 Q2 Tip Wage Report.csv', skiprows=2)

# %%
manual = pd.read_csv('data/Manual - 2021 Q2 Tip Wage Report.csv', usecols=[i for i in range(22)])

# %% [markdown]
# ## Cleaning ESSP Data

# %%
# viewing dataframe top rows
essp.head()
# Out:
#    EMPLOYER  ACCOUNT  ID YEARQUARTER       EMPLOYERNAME       BUSINESSNAME  \
# 0                  10603      2021-2  P & P CORPORATION  P & P CORPORATION
# 1                  10603      2021-2  P & P CORPORATION  P & P CORPORATION
# 2                  10603      2021-2  P & P CORPORATION  P & P CORPORATION
# 3                  10603      2021-2  P & P CORPORATION  P & P CORPORATION
# 4                  10603      2021-2  P & P CORPORATION  P & P CORPORATION
#
#      AGENTNAME    PHONE  NUM                     EMAIL  \
# 0  PAYCE  INC.  4.432799e+09  martin@lachaumieredc.com
# 1  PAYCE  INC.  4.432799e+09  martin@lachaumieredc.com
# 2  PAYCE  INC.  4.432799e+09  martin@lachaumieredc.com
# 3  PAYCE  INC.  4.432799e+09  martin@lachaumieredc.com
# 4  PAYCE  INC.  4.432799e+09  martin@lachaumieredc.com
#
#                                  MAILINGADDRESS  \
# 0  1220B E JOPPA ROAD #324,TOWSON,MD 21286
# 1  1220B E JOPPA ROAD #324,TOWSON,MD 21286
# 2  1220B E JOPPA ROAD #324,TOWSON,MD 21286
# 3  1220B E JOPPA ROAD #324,TOWSON,MD 21286
# 4  1220B E JOPPA ROAD #324,TOWSON,MD 21286
#
#                                        DCWORKADDRESS  \
# 0  2813 M ST NW                            ,WASHI...
# 1  2813 M ST NW                            ,WASHI...
# 2  2813 M ST NW                            ,WASHI...
# 3  2813 M ST NW                            ,WASHI...
# 4  2813 M ST NW                            ,WASHI...
#
#                         SSN       EMPLOYEENAME  TIPPED  WAGE  HOURS  \
# 0  bvOpVg7uC2QpWOIdmncShA==   FELIPE VELASQUEZ                  272
# 1  f4jFCsunNbBCJRXxgCdWAw==      PETER KRIDLER                  255
# 2  GsEq+iFu17oUjjiL9U5ZtQ==  ABDELLATIF AMMOUR                   66
# 3  ock2FoIzG5Q63rBjvvbsGQ==       RENE GUEVARA                  335
# 4  RoAoUtRP/F8cg+MQYfq5dw==       ELMER FLORES                  387
#
#   EMPLOYER  PAID  HOURLY  RATE  WAGES  AMT TIPPED  WAGES  AMOUNT  \
# 0                       $5.00   $1,360.00            $19,002.00
# 1                       $5.00   $1,275.00            $18,022.00
# 2                       $5.00     $330.00             $2,954.00
# 3                       $5.00   $1,677.00            $20,859.00
# 4                       $5.00   $1,935.00            $11,552.00
#
#   AVGTOTALHOURLYRATE AVGHOURLYTIPSRECEIVED MINWAGEMET COMPLIANCEBASERATE  \
# 0            $74.86                $69.86         Yes                Yes
# 1            $75.67                $70.67         Yes                Yes
# 2            $49.76                $44.76         Yes                Yes
# 3            $67.27                $62.27         Yes                Yes
# 4            $34.85                $29.85         Yes                Yes
#
#   FILING  DATE
# 0    7/31/2021
# 1    7/31/2021
# 2    7/31/2021
# 3    7/31/2021
# 4    7/31/2021

# %%
# subsetting
essp = essp[["EMPLOYERNAME", "TIPPED  WAGE  HOURS", "EMPLOYER  PAID  HOURLY  RATE", "WAGES  AMT", "TIPPED  WAGES  AMOUNT", "AVGTOTALHOURLYRATE", "AVGHOURLYTIPSRECEIVED"]]

# %%
# renaming columns
essp = essp.rename(columns={"EMPLOYERNAME": "emp_name",
                        "TIPPED  WAGE  HOURS": "hours_worked",
                        "EMPLOYER  PAID  HOURLY  RATE": "hourly_rate_emp", 
                        "WAGES  AMT": "total_wage", 
                        "TIPPED  WAGES  AMOUNT": "total_tips", 
                        "AVGTOTALHOURLYRATE": "hourly_rate_avg", # calculated column
                        "AVGHOURLYTIPSRECEIVED": "tips_avg"})

# %%
# adding source column
essp['source'] = 'ESSP'

# %%
essp.head()
# Out:
#             emp_name  hours_worked hourly_rate_emp  total_wage   total_tips  \
# 0  P & P CORPORATION           272          $5.00   $1,360.00   $19,002.00
# 1  P & P CORPORATION           255          $5.00   $1,275.00   $18,022.00
# 2  P & P CORPORATION            66          $5.00     $330.00    $2,954.00
# 3  P & P CORPORATION           335          $5.00   $1,677.00   $20,859.00
# 4  P & P CORPORATION           387          $5.00   $1,935.00   $11,552.00
#
#   hourly_rate_avg tips_avg source
# 0         $74.86   $69.86    ESSP
# 1         $75.67   $70.67    ESSP
# 2         $49.76   $44.76    ESSP
# 3         $67.27   $62.27    ESSP
# 4         $34.85   $29.85    ESSP

# %%
# extracting values from string columns
essp["hourly_rate_emp"] = essp["hourly_rate_emp"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float')
essp["total_wage"] = essp["total_wage"].str.extract(r"([-+]?\d*\,\d*\.\d+|[-+]?\d*\.\d+|[-+]\d+)")
essp["total_tips"] = essp["total_tips"].str.extract(r"([-+]?\d*\,\d*\.\d+|[-+]?\d*\.\d+|[-+]\d+)")
essp["hourly_rate_avg"] = essp["hourly_rate_avg"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float') # calculated column
essp["tips_avg"] = essp["tips_avg"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float')

# %%
# replacing comma in total wages and total tips, and converting to float
essp["total_wage"] = essp["total_wage"].str.replace(',', '').astype('float')
essp["total_tips"] = essp["total_tips"].str.replace(',', '').astype('float')

# %% [markdown]
# ## Cleaning Manual Data

# %%
# viewing dataframe top rows
manual.head()
# Out:
#    EAN Year-Quarter            Employer Name              Business Name  \
# 0  A.W      2021-Q2  Hank's on the Wharf, LLC  Hank's on the Wharf, LLC
# 1  A.W      2021-Q2  Hank's on the Wharf, LLC  Hank's on the Wharf, LLC
# 2  A.W      2021-Q2  Hank's on the Wharf, LLC  Hank's on the Wharf, LLC
# 3  A.W      2021-Q2  Hank's on the Wharf, LLC  Hank's on the Wharf, LLC
# 4  A.W      2021-Q2  Hank's on the Wharf, LLC  Hank's on the Wharf, LLC
#
#       Agent Name Contact Phone #       Contact E-Mail       Street Address  \
# 0   JEFF STRINE    202-271-4206   jstrine@hanksdc.com  701 Wharf Street SW
# 1   JEFF STRINE    202-271-4206   jstrine@hanksdc.com  701 Wharf Street SW
# 2   JEFF STRINE    202-271-4206   jstrine@hanksdc.com  701 Wharf Street SW
# 3   JEFF STRINE    202-271-4206   jstrine@hanksdc.com  701 Wharf Street SW
# 4   JEFF STRINE    202-271-4206   jstrine@hanksdc.com  701 Wharf Street SW
#
#         City, State, Zip Employee Name  (2,975 Employee records)  ...  \
# 0  Washington, DC  20024                            Vilma Alfaro  ...
# 1  Washington, DC  20024                            Vilma Alfaro  ...
# 2  Washington, DC  20024                        Estefany Alvarez  ...
# 3  Washington, DC  20024                        Estefany Alvarez  ...
# 4  Washington, DC  20024                          Kokouvi Apetoh  ...
#
#    Total Employer Paid Wages During Quarter   \
# 0                                 $5,608.90
# 1                                   $284.71
# 2                                 $3,087.70
# 3                                    $30.75
# 4                                 $2,079.24
#
#     Total Tips Received During Quarter   Actual Employer Paid Hourly Rate   \
# 0                             $9,048.88                            $11.00
# 1                                 $0.00                            $18.50
# 2                             $5,915.20                             $7.50
# 3                             $2,030.17                            $15.00
# 4                            $4,982.62                              $7.50
#
#    Avg. Hourly Tips Received   \
# 0                     $17.75
# 1                       $-
# 2                     $14.37
# 3                    $990.33
# 4                     $17.97
#
#    Avg. Total Hourly Rate (Employer Paid And Tips)   \
# 0                                           $28.75
# 1                                           $18.50
# 2                                           $21.87
# 3                                        $1,005.33
# 4                                           $25.47
#
#    Minimum Wage Met? (224 Potential Violations)   \
# 0                                            YES
# 1                                            YES
# 2                                            YES
# 3                                            YES
# 4                                            YES
#
#    Tipped Base Rate In Compliance?    Wages Due   Wages Received   \
# 0                               YES   $6,373.75       $14,657.78
# 1                               YES     $192.38          $284.71
# 2                               YES   $5,146.13        $9,002.90
# 3                               YES      $25.63        $2,060.92
# 4                               YES   $3,465.38        $7,061.86
#
#     Wages Owed
# 0   $(8,284.03)
# 1      $(92.34)
# 2   $(3,856.78)
# 3   $(2,035.30)
# 4   $(3,596.49)
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Cleaning Manual Data

# %%
# subsetting
manual = manual[["Employer Name ",  "Total Hours Worked During Quarter", " Total Employer Paid Wages During Quarter ", " Total Tips Received During Quarter ", " Actual Employer Paid Hourly Rate ", " Avg. Hourly Tips Received ", " Avg. Total Hourly Rate (Employer Paid And Tips) "]]

# %%
# renaming columns
manual = manual.rename(columns={"Employer Name ": "emp_name",
                                "Total Hours Worked During Quarter": "hours_worked",
                                " Total Employer Paid Wages During Quarter ": "total_wage",
                                " Total Tips Received During Quarter ": "total_tips",
                                " Actual Employer Paid Hourly Rate ": "hourly_rate_emp",
                                " Avg. Hourly Tips Received ": "tips_avg",
                                " Avg. Total Hourly Rate (Employer Paid And Tips) ": "hourly_rate_avg"})

# %%
# adding source column
manual['source'] = 'Manual'

# %%
# extracting values from string columns
manual["hourly_rate_emp"] = manual["hourly_rate_emp"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float')
manual["total_wage"] = manual["total_wage"].str.extract(r"([-+]?\d*\,\d*\.\d+|[-+]?\d*\.\d+|[-+]\d+)")
manual["total_tips"] = manual["total_tips"].str.extract(r"([-+]?\d*\,\d*\.\d+|[-+]?\d*\.\d+|[-+]\d+)")
manual["hourly_rate_avg"] = manual["hourly_rate_avg"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float') # calculated column
manual["tips_avg"] = manual["tips_avg"].str.extract(r"([-+]?\d*\.\d+|[-+]\d+)").astype('float')

# %%
# replacing comma in total wages and total tips, and converting to float
manual["total_wage"] = manual["total_wage"].str.replace(',', '').astype('float')
manual["total_tips"] = manual["total_tips"].str.replace(',', '').astype('float')

# %% [markdown]
# ## Combining Datasets: ESSP, Manual

# %%
combined = essp.append(manual)

# %%
combined.head()
# Out:
#             emp_name  hours_worked  hourly_rate_emp  total_wage  total_tips  \
# 0  P & P CORPORATION         272.0              5.0      1360.0     19002.0
# 1  P & P CORPORATION         255.0              5.0      1275.0     18022.0
# 2  P & P CORPORATION          66.0              5.0       330.0      2954.0
# 3  P & P CORPORATION         335.0              5.0      1677.0     20859.0
# 4  P & P CORPORATION         387.0              5.0      1935.0     11552.0
#
#    hourly_rate_avg  tips_avg source
# 0            74.86     69.86   ESSP
# 1            75.67     70.67   ESSP
# 2            49.76     44.76   ESSP
# 3            67.27     62.27   ESSP
# 4            34.85     29.85   ESSP

# %%
# qc step: convert negative hour values to positive
combined['hours_worked'] = abs(combined['hours_worked'])

# %%
# dropping rows without employer name
combined.dropna(subset = ["emp_name"], inplace=True)

# %%
# replacing missing values with 0
combined = combined.fillna(0)

# %%
# setting index
combined = combined.set_index('emp_name')

# %%
# dropping rows containing all 0's 
combined = combined.loc[~(combined[['hours_worked', 'hourly_rate_emp', 'total_wage', 'total_tips', 'hourly_rate_avg', 'tips_avg']]==0).all(axis=1)]

# %% [markdown]
# #### Saving Data

# %%
combined.to_csv('1_cleaned_data.csv')
