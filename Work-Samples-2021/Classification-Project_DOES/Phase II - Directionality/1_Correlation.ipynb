# %% [markdown]
# #### Analyst: Dhruv Singh <br> Report Name: ML Model, Phase 3 <br> Report Quarter, Year: FY 2011-2021 <br> Date Updated: 08/31/2021

# %% [markdown]
# # Phase III: ML Model

# %%
# libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
import matplotlib.pyplot as plt
import re

df = pd.read_csv('cleaned_data/df.csv')

# %%
# Drop unnecccessary features and split into training/test sets
features = df.drop(['Employed'], axis=1)
labels = df['Employed']

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
X_train.head()
# Out:
#        Age_AtReg  Disability  Gender  CitizenStatus  EducationLevel  \
# 14337         23         0.0       1              1            16.0
# 17117         26         0.0       2              1            11.0
# 32590         45         0.0       2              1            14.0
# 55811         53         0.0       1              1            14.0
# 40120         57         1.0       1              1            14.0
#
#        Race_Hispanic  Race_NativeAmerican  Race_Asian  Race_AfricanAmerican  \
# 14337              0                    0           0                     1
# 17117              0                    0           0                     1
# 32590              0                    0           0                     0
# 55811              0                    0           0                     1
# 40120              0                    0           0                     1
#
#        Race_PacificIslander  ...  Month  Year  BTW  DCCC  DCIA  LEAP  LTA  \
# ...

# %%
model = sm.Logit(df.Employed, df.drop(['Employed'], axis=1))
result = model.fit()
result.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.531527
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Employed   No. Observations:                58645
# Model:                          Logit   Df Residuals:                    58623
# Method:                           MLE   Df Model:                           21
# Date:                Fri, 10 Sep 2021   Pseudo R-squ.:                 0.07065
# Time:                        17:14:01   Log-Likelihood:                -31171.
# converged:                       True   LL-Null:                       -33541.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                            coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...
